# %%
from mne_lsl.stream import StreamLSL as Stream


stream = Stream(bufsize=60).connect()
stream.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 36 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  nchan: 36
#  projs: []
#  sfreq: 250.0 Hz
# >

# %%
import matplotlib.pyplot as plt
import numpy as np

data, ts = stream.get_data()

plt.figure()
plt.scatter(np.arange(len(ts)), ts)
plt.show()
# Out:
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
import mne
raw = mne.io.RawArray(data, stream.info)
raw.set_channel_types({'CWL1': 'misc', 'CWL2': 'misc', 'CWL3': 'misc', 'CWL4': 'misc', 'ECG': 'ecg'})
# Out:
# Creating RawArray with float64 data, n_channels=36, n_times=15000
#     Range : 0 ... 14999 =      0.000 ...    59.996 secs
# Ready.
# C:\Users\victor.ferat\AppData\Local\Temp\ipykernel_28464\3084484023.py:3: RuntimeWarning: The unit for channel(s) CWL1, CWL2, CWL3, CWL4 has changed from V to NA.
#   raw.set_channel_types({'CWL1': 'misc', 'CWL2': 'misc', 'CWL3': 'misc', 'CWL4': 'misc', 'ECG': 'ecg'})
# <RawArray | 36 x 15000 (60.0 s), ~4.2 MB, data loaded>

# %%
raw.plot_psd(fmax=100)
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# C:\Users\victor.ferat\AppData\Local\Temp\ipykernel_28464\1643215239.py:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd(fmax=100)
# c:\Users\victor.ferat\AppData\Local\miniconda3\envs\mne-lsl\lib\site-packages\mne\viz\utils.py:165: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>
